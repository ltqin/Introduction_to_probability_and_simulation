# %% [markdown]
# # Python does not leave

# %% [markdown]
# ## Contents
#
# * [Functions](#functions)
# * [Probability axioms](#probability_axioms)

# %% [markdown]
# ## Functions <a name="functions"></a>

# %% [markdown]
# Sometime the best way to describe something is with a picture.

# %%
# Don't worry about the code. Just look at the picture.
from IPython.display import Image
Image('../fig/functions.png')

# %%
So from the picture a function takes some inputs and then transforms the inputs into outputs.
Function are great because it means we don't have to re
